# %%
age = 10
if age >= 18 :
    print("You are eligible to DL.")
    print("You can apply for DL.")
else :
    print("You are not eligible to DL.")
    print("You cannot apply for DL.")
print("This is the end of the program.")
# Out:
# You are not eligible to DL.
# You cannot apply for DL.
# This is the end of the program.

# %%
#how to take input from user
age = input("Enter your age : ")
name = input("Enter your name : ")

##### by default input function takes input as string. we need to convert it to int if we want to use it as number.

n = int(input("Enter a number : "))
print(n*2)
m = float(input("Enter a number : "))
print(m*2)
print(m+n)
# Out:
# 684
# 6.9

# %%
marks = int(input("Enter your marks"))
print(marks)
if marks >= 90 :
    print("You got A grade.")
elif marks >= 80 :
    print("You got B grade.")
elif marks >= 70 :
    print("You got C grade.")
elif marks >= 60 :
    print("You got D grade.")
else :
    print("You got F grade.")
# Out:
# 97
# You got A grade.

# %%
------pendingggg------
# Out:
#   Cell In[17], line 1
#     ------pendingggg------
#                           ^
# SyntaxError: invalid syntax
