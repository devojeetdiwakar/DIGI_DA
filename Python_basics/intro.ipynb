# %% [markdown]
# it is my first day at digipodium and i am learning python

# %%
name = "Devojeet Diwakar"
name
print(name)
type(name)
s = """This is a string
he is very good boy """
print(s)
type(s)
s
# Out:
# Devojeet Diwakar
# This is a string
# he is very good boy
# 'This is a string\nhe is very good boy '

# %%
ishungry = True
ishungry
type(ishungry)
# Out:
# bool

# %%
a,b = 10, 20

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
a=[1,2.0,"python",True]

# %%
a
# Out:
# [1, 2.0, 'python', True]

# %%
print(a)
# Out:
# [1, 2.0, 'python', True]

# %%
type(a)
# Out:
# list

# %%
v = (1,2.3,"tyes",False)

# %%
print(v)
v
# Out:
# (1, 2.3, 'tyes', False)
# (1, 2.3, 'tyes', False)

# %%
w = {1,1,1,1,3.4,"tew","python",True}
print(w)
type(w)
# Out:
# {1, 'python', 3.4, 'tew'}
# set

# %%
q = {"abc" : 1, "def" : 2, "ghi" : 3}
print(q)
print(q["abc"])
type(q)
# Out:
# {'abc': 1, 'def': 2, 'ghi': 3}
# 1
# dict
